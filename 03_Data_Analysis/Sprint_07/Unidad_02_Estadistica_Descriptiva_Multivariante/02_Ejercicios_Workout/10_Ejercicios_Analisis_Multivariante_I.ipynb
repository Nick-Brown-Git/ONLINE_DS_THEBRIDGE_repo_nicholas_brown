# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para ejercitarte y afianzar lo aprendido sobre el análisis bivariante, completa los siguientes ejercicios. Recuerda que necesitarás datos que están en el directorio data que acompaña al notebook (búscalo en el repositorio de ejercicios)
#
# La solución a los mismos se subirá a lo largo del sprint.

# %% [markdown]
# ### Ejercicio 0
#
#
# Importa los paquetes y módulos que necesites a lo largo del notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from bootcampviztools import plot_categorical_relationship_fin, pinta_distribucion_categoricas

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# Carga el dataset de admisiones que conoces de la unidad anterior y que se encuentra en la ruta "./data/admission_data.csv", deshazte de las columnas innecesarias

# %%
df_admission = pd.read_csv("./data/admission_data.csv")

# %%
df_admission.drop(columns="Unnamed: 0",inplace=True)

# %%
df_admission.head()
# Out:
#    Year                    Major Gender Admission
# 0  1973       School of Medicine      F  Rejected
# 1  1973  Department of Economics      M  Accepted
# 2  1973                    Other      F  Accepted
# 3  1973                    Other      M  Accepted
# 4  1973                    Other      M  Rejected

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# Haz el análisis bivariante de "Admission" y "Major" (emplea las funciones del workout importándolas del módulo `bootcampviztools`, o utiliza las visualizaciones del notebook en el repositorio) y contesta a las siguientes preguntas:
# * ¿Cuál es el departamento con el mayor porcentaje de admsiones?¿Y el de menor?
# * ¿Existe alguna diferencia destacada entre los departamentos?

# %%
pinta_distribucion_categoricas(df_admission,["Admission","Major"],giro = 45)

# %%
plot_categorical_relationship_fin(df_admission,"Admission","Major",show_values=True)

# %%
plot_categorical_relationship_fin(df_admission,"Admission","Major", relative_freq=True,show_values=True)

# %% [markdown]
# ### Ejercicio 3
#
# Repite el análisis para "Admission" y "Gender" y responde a las siguientes preguntas:
# * ¿Existe una diferencia visual significativa entre el porcentaje de admitidos de cada género?
# * ¿Cuál de los dos grupos tiene más admisiones?

# %%
pinta_distribucion_categoricas(df_admission,["Admission","Gender"],giro = 45)

# %%
plot_categorical_relationship_fin(df_admission,"Admission","Gender",show_values=True)

# %%
plot_categorical_relationship_fin(df_admission,"Admission","Gender",relative_freq=True,show_values=True)

# %% [markdown]
# ### Ejercicio 4
#
# Carga el dataset de propinas (tips) que conoces de la unidad anterior y que se encuentra en la ruta "./data/tips.csv", deshazte de las columnas innecesarias

# %%
df_tips = pd.read_csv("./data/tips.csv")

# %%
df_tips.drop(columns="Unnamed: 0",inplace=True)
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Ejercicio 5
#
# Haz el análisis bivariante de "tip" y "sex" (emplea las funciones del workout importándolas del módulo `bootcampviztools`, o utiliza las visualizaciones del notebook en el repositorio), añade el cálculo de la media y mediana de la variable continua por cada valor de la variable categórica, y contesta a las siguientes preguntas:
# * ¿Existe alguna diferencia visualmente significativa entre las propinas de los grupos de la variable "sex"?
# * ¿Son diferentes respecto al  conjunto total?

# %%
from bootcampviztools import plot_categorical_numerical_relationship, plot_combined_graphs, \
    pinta_distribucion_categoricas, plot_grouped_boxplots, plot_grouped_histograms

# %%
pinta_distribucion_categoricas(df_tips,["sex"],relativa=True,mostrar_valores=True)

# %%
plot_combined_graphs(df_tips,["tip"])
# Out:
# (2,)

# %%
plot_categorical_numerical_relationship(df_tips,"sex","tip", measure = "median")

# %%
plot_categorical_numerical_relationship(df_tips,"sex","tip", measure = "mean")

# %%
plot_grouped_boxplots(df_tips,"sex","tip")

# %%
plot_grouped_histograms(df_tips,"sex","tip",2)

# %% [markdown]
# * Hay una diferencia en el porcentaje de hombres que dejan propina y el porcentaje de mujeres que dejan propina; sin embargo, esto podría deberse simplemente al hecho de que hay más hombres pagando la cuenta y dejando propina que mujeres.
#
# * En cuanto a la cantidad de propina que deja cada sexo, no hay una diferencia significativa. La propina promedio que dejan ambos es un poco inferior a 3 dólares.
#
# * Vemos que hay una ligera diferencia en la cantidad de propina que dejan los hombres, dejando una propina ligeramente más alta.

# %% [markdown]
# ### Ejercicio 6
#
# Repite el análisis pero esta vez para "tip" y "smoker", añade también el cálculo de la media y de la mediana de la variable continua por cada valor de la variable categórica, y contesta a las siguiente pregunta:
# * ¿Existe alguna diferencia visualmente significativa entre las propinas de los grupos de la variable "smoker"?

# %%
pinta_distribucion_categoricas(df_tips,["smoker"],relativa=True,mostrar_valores=True)

# %%
plot_categorical_numerical_relationship(df_tips,"smoker","tip", measure = "median")

# %%
plot_categorical_numerical_relationship(df_tips,"sex","tip", measure = "mean")

# %%
plot_grouped_boxplots(df_tips,"smoker","tip")

# %%
plot_grouped_histograms(df_tips,"smoker","tip",2)

# %% [markdown]
# No hay una diferencia visualmente muy significativa.

# %% [markdown]
# ### Ejericicio 7
#
# Carga ahora el datase de accidentes de coches, que se encuentra en la ruta "./data/car_crashes.csv" y deshazte de las columnas innecesarias

# %%
df_cars = pd.read_csv("./data/car_crashes.csv",sep = "|")

# %%
df_cars.head(5)
# Out:
#    Unnamed: 0  total  speeding  ...  ins_premium  ins_losses  abbrev
# 0           0   18.8     7.332  ...       784.55      145.08      AL
# 1           1   18.1     7.421  ...      1053.48      133.93      AK
# 2           2   18.6     6.510  ...       899.47      110.35      AZ
# 3           3   22.4     4.032  ...       827.34      142.39      AR
# 4           4   12.0     4.200  ...       878.41      165.63      CA
#
# [5 rows x 9 columns]

# %%
df_cars = df_cars.drop(columns = "Unnamed: 0")

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
from bootcampviztools import grafico_dispersion_con_correlacion

# %% [markdown]
# ### Ejercicio 8
#
# Haz un analisis bivairante entre "total" y "speeding". Muestra su diagrama de dispersión y su valor de correlación de pearson obtenido con pandas. Luego contesta a la siguiente pregunta
# * ¿Existe alguna relación visual entre las variables?¿Y numérica?

# %%
plot_combined_graphs(df_cars,["total"])
# Out:
# (2,)

# %%
plot_combined_graphs(df_cars,["speeding"])
# Out:
# (2,)

# %%
df_cars[["total","speeding"]].describe()
# Out:
#            total   speeding
# count  51.000000  51.000000
# mean   15.790196   4.998196
# std     4.122002   2.017747
# min     5.900000   1.792000
# 25%    12.750000   3.766500
# 50%    15.600000   4.608000
# 75%    18.500000   6.439000
# max    23.900000   9.450000

# %%
df_cars[["total","speeding"]].corr()
# Out:
#              total  speeding
# total     1.000000  0.611548
# speeding  0.611548  1.000000

# %%
grafico_dispersion_con_correlacion(df_cars,"total","speeding")

# %% [markdown]
# Si existe una relacion visual. Los estados con mas accidentes totales tienden a tener mas accidentes por exceso de velocidad
# Y numerica, si , el coeficiente de peason es positiva y moderamente fuerte a 0.6

# %% [markdown]
# ### Ejercicio 9
#
# Usa scipy tal como lo hicimos en el workout para hacer el test de correlación. ¿Cuál es el p-value?¿Qué podemos decir de la correlación lineal entre "total" y "speeding"?

# %%
from scipy.stats import pearsonr

pearsonr(df_cars["total"], df_cars["speeding"])
# Out:
# PearsonRResult(statistic=np.float64(0.6115476008001186), pvalue=np.float64(1.8670391109056657e-06))

# %%
grafico_dispersion_con_correlacion(df_cars,"total","speeding", 20, mostrar_correlacion = True)

# %% [markdown]
# p_value = 1.8670391109056657e-06
#
# existe una correlacion lineal, pero no muy fuerte.
